# %% [markdown]
# <a href="https://colab.research.google.com/github/aa-amory/ICDAR-2019-SROIE/blob/master/CeADAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
nb_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0,nb_path)
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
# !./make.sh

# %%
# !pip install easyocr

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])

# %%
Image("/content/ICDAR-2019-SROIE/task1/CTPN Method/data/demo/1000-receipt.jpg")

# %%
output = reader.readtext('/content/ICDAR-2019-SROIE/task1/CTPN Method/data/demo/1000-receipt.jpg')

# %%
output
# Out:
# [([[333, 269], [469, 269], [469, 313], [333, 313]],
#   'GIEEII FIELO',
#   0.3067030144158984),
#  ([[268, 306], [320, 306], [320, 332], [268, 332]],
#   '5305',
#   0.9976053654362977),
#  ([[326, 308], [544, 308], [544, 334], [326, 334]],
#   'E PACIFIC COAST IIIY',
#   0.7438712519281728),
#  ([[288, 331], [408, 331], [408, 358], [288, 358]],
#   'Long Beach',
#   0.9386433750902391),
#  ([[424, 332], [522, 332], [522, 360], [424, 360]],
#   'CA go8O!',
#   0.1301024929368347),
#  ([[324, 356], [384, 356], [384, 382], [324, 382]],
#   '5GE)',
#   0.23140463251013754),
#  ([[390, 358], [486, 358], [486, 384], [390, 384]],
#   '597 -0906',
#   0.7873647795506098),
#  ([[174, 404], [248, 404], [248, 430], [174, 430]],
#   'Server',
#   0.999652504130351),
#  ([[261, 404], [350, 404], [350, 434], [261, 434]],
#   'Franc is',
#   0.5528690378556834),
#  ([[514, 410], [614, 410], [614, 434], [514, 434]],
#   'Stat ioll:',
#   0.8944146869472193),
# ...

# %%
cord = output[20][0]
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
image = cv2.imread('/content/ICDAR-2019-SROIE/task1/CTPN Method/data/demo/1000-receipt.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
